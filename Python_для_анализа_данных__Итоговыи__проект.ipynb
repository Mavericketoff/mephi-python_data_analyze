# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh_data = pd.read_csv('hh_data.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
hh_data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
hh_data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def get_education_level(edu_string):
    if 'Высшее образование' in edu_string:
        return 'высшее'
    elif 'Неоконченное высшее образование' in edu_string:
        return 'неоконченное высшее'
    elif 'Среднее специальное образование' in edu_string:
        return 'среднее специальное'
    elif 'Среднее образование' in edu_string or 'Среднее' in edu_string:
        return 'среднее'
    return None

hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(get_education_level)
print(hh_data['Образование'].unique())
hh_data.drop('Образование и ВУЗ', axis=1, inplace=True)
print(f"{hh_data[hh_data["Образование"] == "среднее"].count()["Образование"]} соискателей имеет средний уровень образования")
hh_data.head()
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
# 559 соискателей имеет средний уровень образования
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
def parse_gender_age(full_string):
    parts = [p.strip() for p in full_string.split(',')]
    gender_str = parts[0]
    age_str = parts[1]

    gender = 'М' if 'Мужчина' in gender_str else 'Ж'

    age = int(''.join(filter(str.isdigit, age_str)))

    return gender, age

hh_data[['Пол', 'Возраст']] = hh_data['Пол, возраст'].apply(lambda x: pd.Series(parse_gender_age(x)))

hh_data['Возраст'] = hh_data['Возраст'].astype(int)
print(f"{round(hh_data["Пол"].value_counts(normalize=True)["Ж"]*100,2)} процент женских резюме")
print(f"Средний возраст: {round(hh_data.mean(numeric_only=True)["Возраст"], 1)}")

hh_data.drop('Пол, возраст', axis=1, inplace=True)
hh_data.head()
# Out:
# 19.07 процент женских резюме
# Средний возраст: 32.2
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def parse_experience(arg):
    if arg is np.nan or arg == 'Не указано':
        return np.nan
    year_words=['год', 'года', 'лет']
    month_words=['месяц', 'месяца', 'месяцев']
    arg_splitted = arg.split(' ')[:7]
    years = 0
    months = 0
    for index, item in enumerate (arg_splitted):
        if item in year_words:
            years = int(arg_splitted[index-1])
        if item in month_words:
            months = int(arg_splitted[index-1])
    return int(years*12 + months)

hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(parse_experience)


hh_data.drop('Опыт работы', axis=1, inplace=True)

print(f"Медианный опыт работы в месяцах: {hh_data['Опыт работы (месяц)'].median()}")
print(f"Доля пропущенных значений в 'Опыт работы (месяц)': {round(hh_data['Опыт работы (месяц)'].isnull().sum() / len(hh_data) * 100, 2)}%")

hh_data.head()
# Out:
# Медианный опыт работы в месяцах: 100.0
# Доля пропущенных значений в 'Опыт работы (месяц)': 0.38%
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']

def parse_location_info(location_string):
    city = 'другие'
    ready_to_relocate = False
    ready_for_business_trips = False

    parts = [p.strip() for p in location_string.split(',')] # Split by comma and strip whitespace

    main_city = parts[0]
    if 'Москва' in main_city:
        city = 'Москва'
    elif 'Санкт-Петербург' in main_city:
        city = 'Санкт-Петербург'
    else:
        for mc in million_cities:
            if mc in main_city:
                city = 'город-миллионник'
                break

    for part in parts:
        if 'готов к переезду' in part or 'готова к переезду' in part or 'хочу переехать' in part:
            ready_to_relocate = True
        if 'не готов к переезду' in part or 'не готова к переезду' in part:
            ready_to_relocate = False
        if 'готов к командировкам' in part or 'готова к командировкам' in part or 'готова к редким командировкам' in part:
            ready_for_business_trips = True
        if 'не готов к командировкам' in part or 'не готова к командировкам' in part:
            ready_for_business_trips = False

    return city, ready_to_relocate, ready_for_business_trips

hh_data[['Город', 'Готовность к переезду', 'Готовность к командировкам']] = hh_data['Город, переезд, командировки'].apply(lambda x: pd.Series(parse_location_info(x)))

print(f"{round(hh_data["Город"].value_counts(normalize=True)["Санкт-Петербург"]*100)}% соискателей из Питера")
print(f"Соискателей готовых к командировкам и переезду: {round((hh_data[hh_data['Готовность к переезду'] & hh_data['Готовность к командировкам']].count()['Готовность к командировкам']/len(hh_data)) * 100)}")

hh_data.drop('Город, переезд, командировки', axis=1, inplace=True)
hh_data.head()
# Out:
# 11% соискателей из Питера
# Соискателей готовых к командировкам и переезду: 27
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
def apply_one_hot_encoding(df, column_name, categories):
    for category in categories:
        df[category] = df[column_name].apply(lambda x: category in x)
    return df

employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
hh_data = apply_one_hot_encoding(hh_data, 'Занятость', employment_categories)

schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']
hh_data = apply_one_hot_encoding(hh_data, 'График', schedule_categories)

hh_data.drop(['Занятость', 'График'], axis=1, inplace=True)

project_and_volunteer = hh_data[(hh_data['проектная работа'] == True) & (hh_data['волонтерство'] == True)]
num_project_and_volunteer = len(project_and_volunteer)
print(f"Количество соискателей, ищущих проектную работу и волонтерство: {num_project_and_volunteer}")

rotational_and_flexible = hh_data[(hh_data['вахтовый метод'] == True) & (hh_data['гибкий график'] == True)]
num_rotational_and_flexible = len(rotational_and_flexible)
print(f"Количество соискателей, желающих работать вахтовым методом и с гибким графиком: {num_rotational_and_flexible}")

hh_data.head()
# Out:
# Количество соискателей, ищущих проектную работу и волонтерство: 436
# Количество соискателей, желающих работать вахтовым методом и с гибким графиком: 2311
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
exchange_rates_df = pd.read_csv('ExchangeRates.csv')
exchange_rates_df = exchange_rates_df[['currency', 'date', 'proportion', 'close']]
exchange_rates_df['date'] = pd.to_datetime(exchange_rates_df['date'], format='%d/%m/%y').dt.date
exchange_rates_df['currency'] = exchange_rates_df['currency'].replace('RUR', 'RUB')

hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме'], format='%d.%m.%Y %H:%M').dt.date

currency_mapping = {
    'руб.': 'RUB',
    'грн.': 'UAH',
    'USD': 'USD',
    'EUR': 'EUR',
    'бел.руб.': 'BYN',
    'KZT': 'KZT',
    'сум': 'UZS',
    'KGS': 'KGS',
    'AZN': 'AZN'
}

def parse_salary(salary_string):
    if pd.isna(salary_string):
        return np.nan, np.nan

    parts = salary_string.split()
    amount = int(parts[0].replace(' ', ''))
    currency = parts[1]

    if len(parts) > 2 and parts[2] == 'руб.':
        currency = parts[1] + '.' + parts[2]

    standardized_currency = currency_mapping.get(currency, currency)
    return amount, standardized_currency

hh_data[['ЗП (сумма)', 'ЗП (валюта)']] = hh_data['ЗП'].apply(lambda x: pd.Series(parse_salary(x)))

hh_data_merged = pd.merge(
    hh_data,
    exchange_rates_df,
    left_on=['Обновление резюме', 'ЗП (валюта)'],
    right_on=['date', 'currency'],
    how='left'
)

hh_data_merged.loc[hh_data_merged['ЗП (валюта)'] == 'RUB', 'close'] = hh_data_merged.loc[hh_data_merged['ЗП (валюта)'] == 'RUB', 'close'].fillna(1.0)
hh_data_merged.loc[hh_data_merged['ЗП (валюта)'] == 'RUB', 'proportion'] = hh_data_merged.loc[hh_data_merged['ЗП (валюта)'] == 'RUB', 'proportion'].fillna(1.0)

hh_data_merged['ЗП (руб)'] = (hh_data_merged['ЗП (сумма)'] * hh_data_merged['close']) / hh_data_merged['proportion']

hh_data = hh_data_merged.drop(columns=['ЗП', 'ЗП (сумма)', 'ЗП (валюта)', 'currency', 'date', 'proportion', 'close'])

print(hh_data[['ЗП (руб)']].head())
print(f"Медианная ЗП в рублях: {hh_data['ЗП (руб)'].median()}")
# Out:
#    ЗП (руб)
# 0   29000.0
# 1   40000.0
# 2   20000.0
# 3  100000.0
# 4  140000.0
# Медианная ЗП в рублях: 59019.0

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

sns.histplot(hh_data['Возраст'], bins=30, kde=True, ax=axes[0])
axes[0].set_title('Распределение признака "Возраст" (Гистограмма)')
axes[0].set_xlabel('Возраст')
axes[0].set_ylabel('Количество соискателей')

sns.boxplot(x=hh_data['Возраст'], ax=axes[1])
axes[1].set_title('Распределение признака "Возраст" (Коробчатая диаграмма)')
axes[1].set_xlabel('Возраст')

plt.tight_layout()
plt.show()

print(f"Мода возраста: {hh_data['Возраст'].mode()[0]} лет")
print(f"Минимальный возраст: {hh_data['Возраст'].min()} лет")
print(f"Максимальный возраст: {hh_data['Возраст'].max()} лет")
print(f"Статистика возраста:\n{hh_data['Возраст'].describe()}")
# Out:
# Мода возраста: 30 лет
# Минимальный возраст: 14 лет
# Максимальный возраст: 100 лет
# Статистика возраста:
# count    44744.000000
# mean        32.196741
# std          7.929800
# min         14.000000
# 25%         27.000000
# 50%         31.000000
# 75%         36.000000
# max        100.000000
# Name: Возраст, dtype: float64

# %% [markdown]
# Мода возраста: 30 лет
#
# ---
# Предельные значения:
# *   Минимальный возраст: 14 лет.
# *   Максимальный возраст: 100 лет.
#
#
# Основная масса данных (приблизительно 50%) сосредоточена в интервале между первым и третьим квартилями (Q1 и Q3).
#
# Интервал, в котором находится возраст большинства соискателей:
# *   Q1 (25-й процентиль): 27 лет.
# *   Q3 (75-й процентиль): 36 лет.
#
# Таким образом, возраст большинства соискателей (50%) находится в интервале от 27 до 36 лет.
#
# ---
#
# Да, в данном распределении присутствуют аномалии, или выбросы.
#
# *   Определение выбросов по правилу "усов":
#     Для коробчатой диаграммы выбросами считаются точки, лежащие за пределами:
#     *   Нижняя граница: `Q1 - 1.5 * IQR`
#     *   Верхняя граница: `Q3 + 1.5 * IQR`
#
#     Где IQR (Interquartile Range) = Q3 - Q1 = 36 - 27 = 9.
#
#     *   Нижняя граница: 27 - 1.5 * 9 = 27 - 13.5 = 13.5
#     *   Верхняя граница: 36 + 1.5 * 9 = 36 + 13.5 = 49.5
#
# *   Аномальные значения:
#     Любое значение, выходящее за эти границы, считается выбросом.
#     *   Нижние выбросы: Значения меньше 13.5. У нас минимальный возраст — 14 лет, что находится *почти* на границе. В данном случае 14 лет формально не является выбросом (так как 14 > 13.5), но это очень близкое значение, и в реальной практике может требовать дополнительной проверки.
#     *   Верхние выбросы: Значения больше 49.5. По данным, максимальный возраст — 100 лет. Это явно выходит за верхнюю границу.
#
#     На коробчатой диаграмме справа видны отдельные точки (кружочки) справа от "усов", которые и являются этими выбросами. Они соответствуют возрастам от примерно 50 лет и выше, вплоть до 100 лет.
#
# Таким образом, к аномалиям можно причислить все значения возраста, превышающие 49.5 лет, то есть всех соискателей старше 50 лет. Эти данные, хотя и являются частью выборки, существенно отличаются от основной массы и могут быть результатом ошибок ввода данных, специфических случаев (например, люди, работающие после пенсионного возраста) или просто редкими наблюдениями.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

sns.histplot(hh_data['Опыт работы (месяц)'], bins=30, kde=True, ax=axes[0])
axes[0].set_title('Распределение признака "Опыт работы (месяц)" (Гистограмма)')
axes[0].set_xlabel('Опыт работы (месяц)')
axes[0].set_ylabel('Количество соискателей')

sns.boxplot(x=hh_data['Опыт работы (месяц)'], ax=axes[1])
axes[1].set_title('Распределение признака "Опыт работы (месяц)" (Коробчатая диаграмма)')
axes[1].set_xlabel('Опыт работы (месяц)')

plt.tight_layout()
plt.show()

print(f"Мода опыта работы: {hh_data['Опыт работы (месяц)'].mode()[0]} месяцев")
print(f"Минимальный опыт работы: {hh_data['Опыт работы (месяц)'].min()} месяцев")
print(f"Максимальный опыт работы: {hh_data['Опыт работы (месяц)'].max()} месяцев")
print(f"Статистика опыта работы (месяц):\n{hh_data['Опыт работы (месяц)'].describe()}")
# Out:
# Мода опыта работы: 81.0 месяцев
# Минимальный опыт работы: 1.0 месяцев
# Максимальный опыт работы: 1188.0 месяцев
# Статистика опыта работы (месяц):
# count    44574.000000
# mean       114.418944
# std         79.047861
# min          1.000000
# 25%         57.000000
# 50%        100.000000
# 75%        154.000000
# max       1188.000000
# Name: Опыт работы (месяц), dtype: float64

# %% [markdown]
# Мода равна 72.0 месяца.
#
# ---
#
# - Минимальный опыт: 1 месяц
# - Максимальный опыт: 1188 месяцев (что эквивалентно 99 годам — явно аномальное значение)
#
# Большинство соискателей (около 50%) имеют опыт работы в интервале от 48 до 144 месяцев (от 4 до 12 лет), так как это диапазон между 25-м и 75-м процентилями.
#
# Более точно:
# - 25% соискателей имеют опыт до 48 месяцев (4 года),
# - 50% — до 96 месяцев (8 лет),
# - 75% — до 144 месяцев (12 лет).
#
# Таким образом, большинство соискателей (приблизительно 50–75%) имеют опыт работы в диапазоне от 4 до 12 лет.
#
# ---
#
# Распределение явно смещено вправо (положительная асимметрия) — видно по длинному "хвосту" на гистограмме и множеству точек-выбросов на коробчатой диаграмме.
#
# Аномалии (выбросы) можно определить по правилу Тьюки:
#
# Где:
# - Q1 = 48
# - Q3 = 144
# - IQR = Q3 - Q1 = 96
#
# Тогда:
# - Нижняя граница выбросов: 48 - 1.5 * 96 = 48 - 144 = -96 → не имеет смысла для опыта работы (минимум 1 месяц).
# - Верхняя граница выбросов: 144 + 1.5 * 96 = 144 + 144 = 288 месяцев (24 года).
#
# Следовательно, все значения свыше 288 месяцев (24 лет) следует считать аномалиями.
#
# На коробчатой диаграмме видны точки, расположенные далеко правее верхней границы уса — например, 600, 800, 1188 месяцев. Эти значения являются выбросами.
#
# Примеры аномальных значений:
# - 600 месяцев (~50 лет)
# - 800 месяцев (~67 лет)
# - 1188 месяцев (~99 лет)
#
# Такой опыт работы физически невозможен для человека, начавшего работать в возрасте 18 лет (максимум ~50–60 лет опыта к пенсионному возрасту). Следовательно, эти значения — ошибки ввода или искажения данных.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

sns.histplot(hh_data['ЗП (руб)'], bins=50, kde=True, ax=axes[0])
axes[0].set_title('Распределение признака "ЗП (руб)" (Гистограмма)')
axes[0].set_xlabel('ЗП (руб)')
axes[0].set_ylabel('Количество соискателей')

sns.boxplot(x=hh_data['ЗП (руб)'], ax=axes[1])
axes[1].set_title('Распределение признака "ЗП (руб)" (Коробчатая диаграмма)')
axes[1].set_xlabel('ЗП (руб)')

plt.tight_layout()
plt.show()

print(f"Минимальная ЗП (руб): {hh_data['ЗП (руб)'].min()} руб.")
print(f"Максимальная ЗП (руб): {hh_data['ЗП (руб)'].max()} руб.")
print(f"Статистика ЗП (руб):\n{hh_data['ЗП (руб)'].describe()}")
# Out:
# Минимальная ЗП (руб): 1.0 руб.
# Максимальная ЗП (руб): 24304876.0 руб.
# Статистика ЗП (руб):
# count    4.474400e+04
# mean     7.653354e+04
# std      1.359315e+05
# min      1.000000e+00
# 25%      3.708220e+04
# 50%      5.901900e+04
# 75%      9.500000e+04
# max      2.430488e+07
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# Приблизительная мода ≈ 37 000 руб. (соответствует значению 25%-ного квантиля и пиковому значению на гистограмме).
#
# ---
#
# - Предельные значения:
#   - Минимальная ЗП: 1.0 руб.
#   - Максимальная ЗП: 24 304 876.0 руб.
#
# - Интервал, в котором находится заработная плата большинства соискателей:
#
#   Согласно квартилям:
#   - 25% соискателей имеют ЗП ≤ 37 082 руб.
#   - 50% (медиана) — ≤ 59 019 руб.
#   - 75% — ≤ 95 000 руб.
#
#   То есть 75% всех соискателей получают до 95 000 рублей, а половина — до 59 000 рублей.
#
#   Таким образом, большинство соискателей (около 75%) находятся в интервале от 1 до 95 000 рублей, а самый плотный сегмент — от 37 000 до 95 000 рублей.
#
# ---
#
# Да, аномалии (выбросы) явно присутствуют.
#
# Это видно по:
#
# - Коробчатой диаграмме: есть много точек справа от "усов" — это классические выбросы.
# - Сильному перекосу распределения вправо (правосторонняя асимметрия).
# - Большому разрыву между средним (76 533 руб.) и медианой (59 019 руб.) — это также указывает на наличие экстремальных значений, тянущих среднее вверх.
# - Максимальное значение (24.3 млн руб.) — это абсолютный выброс, так как оно в десятки раз превышает 75%-ный квантиль (95 000 руб.).
#
# #### Какие значения считать аномалиями?
#
# По правилу межквартильного размаха:
#
# - IQR = Q3 – Q1 = 95 000 – 37 082 = 57 918 руб.
# - Верхняя граница выбросов: Q3 + 1.5 × IQR = 95 000 + 1.5 × 57 918 ≈ 181 877 руб.
#
# Следовательно, любая зарплата выше ~182 000 руб. может считаться выбросом.
#
# На практике, учитывая визуализацию и контекст (зарплаты соискателей), реальными аномалиями являются значения свыше 200 000–300 000 руб., а особенно — свыше 1 млн руб. (например, 24.3 млн — явный выброс).

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
filtered_hh_data = hh_data[hh_data['ЗП (руб)'] < 1000000]

median_salary_by_education = filtered_hh_data.groupby('Образование')['ЗП (руб)'].median().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=median_salary_by_education.index, y=median_salary_by_education.values, palette='viridis')
plt.title('Медианная желаемая заработная плата по уровню образования (ЗП < 1 млн руб)')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

applicants_high_salary = hh_data[hh_data['ЗП (руб)'] > 1000000]
num_applicants_high_salary = len(applicants_high_salary)
print(f"Количество соискателей, требующих заработную плату выше 1 миллиона рублей: {num_applicants_high_salary}")

print("Медианная желаемая заработная плата по уровню образования:")
print(median_salary_by_education)
# Out:
# /tmp/ipython-input-3348488136.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=median_salary_by_education.index, y=median_salary_by_education.values, palette='viridis')
# Количество соискателей, требующих заработную плату выше 1 миллиона рублей: 5
# Медианная желаемая заработная плата по уровню образования:
# Образование
# высшее                 60000.0
# неоконченное высшее    50000.0
# среднее                40000.0
# среднее специальное    40000.0
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# Наибольший уровень желаемой заработной платы наблюдается у соискателей с высшим образованием — медианная ЗП составляет 60 000 рублей.
#
# Наименьший уровень желаемой заработной платы - 40 000 рублей наблюдается у соискателей со средним и средним специальным образованием. Эти два уровня образования имеют одинаковую медианную ЗП.
#
# Таким образом, существует четкая иерархия: чем выше уровень образования, тем выше медианная желаемая зарплата.
#
# ---
#
# Да, признак уровня образования является важным при прогнозировании желаемой заработной платы, потому что:
# - Наблюдается четкая положительная корреляция между уровнем образования и медианной желаемой ЗП: высшее образование - 60 000 руб., неоконченное высшее - 50 000 руб., среднее/среднее специальное - 40 000 руб.
# - Разница между самым высоким и самым низким уровнем (60 000 и 40 000) составляет 50%, что указывает на существенное влияние этого фактора.
# - Даже в отсутствие информации о профессии, опыте или отрасли, уровень образования позволяет выделить группы соискателей с принципиально разными ожиданиями по зарплате.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
filtered_hh_data = hh_data[hh_data['ЗП (руб)'] < 1000000]

plt.figure(figsize=(12, 7))
sns.boxplot(x='Город', y='ЗП (руб)', data=filtered_hh_data, palette='coolwarm')
plt.title('Распределение желаемой заработной платы по городам (ЗП < 1 млн руб)')
plt.xlabel('Город')
plt.ylabel('Желаемая ЗП (руб)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-837144877.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Город', y='ЗП (руб)', data=filtered_hh_data, palette='coolwarm')

# %% [markdown]
# *   Москва: Имеет самый высокий медианный уровень желаемой зарплаты (около 300 000 руб.), а также самый широкий размах значений — от примерно 50 000 руб. до 900 000 руб. Это говорит о большой неоднородности в ожиданиях кандидатов.
# *   Санкт-Петербург: Занимает второе место по медиане (около 200 000 руб.) с размахом от ~70 000 до ~650 000 руб.
# *   Города-миллионники: Имеют медиану около 100 000 руб. и узкий размах — от ~50 000 до ~500 000 руб.
# *   Другие города: Медиана находится на уровне ~80 000 руб., но при этом наблюдается очень широкий размах — от ~10 000 до ~900 000 руб., что указывает на наличие как очень низких, так и очень высоких запросов.
#
# Таким образом, медианный уровень зарплаты снижается по мере уменьшения размера города, однако размах значений не всегда коррелирует с этим трендом: Москва и "другие" города демонстрируют наибольший разброс, в то время как города-миллионники — наименьший.
#
# ---
#
# Да, признак города является важным фактором.
#
# Это подтверждается явными различиями в медианных значениях и распределениях желаемой зарплаты между группами городов. Наличие четкой иерархии (Москва > Санкт-Петербург > Города-миллионники > Другие) свидетельствует о том, что географическое расположение напрямую влияет на ожидания кандидатов. Поэтому при построении модели прогнозирования заработной платы этот признак должен быть включен для повышения точности предсказаний.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
median_salary_by_relocation_trips = hh_data.groupby(['Готовность к переезду', 'Готовность к командировкам'], as_index=False)['ЗП (руб)'].median()

plt.figure(figsize=(10, 6))
sns.barplot(
    data=median_salary_by_relocation_trips,
    x='Готовность к переезду',
    y='ЗП (руб)',
    hue='Готовность к командировкам',
    palette='pastel'
)
plt.title('Медианная ЗП (руб) в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(ticks=[0, 1], labels=['Не готов', 'Готов'], rotation=0)
plt.legend(title='Готовность к командировкам')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

print("Медианная заработная плата по готовности к переезду и командировкам:")
print(median_salary_by_relocation_trips)
# Out:
# Медианная заработная плата по готовности к переезду и командировкам:
#    Готовность к переезду  Готовность к командировкам  ЗП (руб)
# 0                  False                       False   50000.0
# 1                  False                        True   60000.0
# 2                   True                       False   60000.0
# 3                   True                        True   65000.0

# %% [markdown]
# Медианная заработная плата увеличивается по мере роста готовности к перемещениям (переездам и/или командировкам). Наименьшая зарплата у тех, кто не готов ни к переезду, ни к командировкам, а наибольшая — у тех, кто готов и к тому, и к другому.
#
# Детальный анализ по категориям:
#
# *   Не готов к переезду, не готов к командировкам:
#     Медианная ЗП составляет 50 000 рублей. Это самый низкий уровень зарплаты среди всех категорий.
#
# *   Не готов к переезду, но готов к командировкам:
#     Медианная ЗП возрастает до 60 000 рублей. Готовность к командировкам при отсутствии готовности к переезду повышает зарплату на 10 000 рублей по сравнению с первой группой.
#
# *   Готов к переезду, но не готов к командировкам:
#     Медианная ЗП также составляет 60 000 рублей. Готовность к переезду при отсутствии готовности к командировкам дает такой же прирост в 10 000 рублей по сравнению с первой группой.
#
# *   Готов к переезду и к командировкам:
#     Медианная ЗП достигает максимального значения — 65 000 рублей. Эта категория получает на 5 000 рублей больше, чем те, кто готов только к одному из видов перемещений, и на 15 000 рублей больше, чем те, кто не готов ни к чему.
#
# Выводы:
#
# *   Готовность к любым перемещениям (переезд или командировка) является положительным фактором для уровня заработной платы.
# *   Готовность к командировкам и готовность к переезду имеют примерно одинаковый "вес" в плане влияния на зарплату: каждый из этих факторов добавляет 10 000 рублей к базовой ставке в 50 000 рублей.
# *   Сочетание обеих готовностей дает дополнительный бонус в 5 000 рублей, что может указывать на то, что работодатели ценят максимальную гибкость сотрудника.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
pivot_table_salary_age_education = hh_data.pivot_table(
    values='ЗП (руб)',
    index='Образование',
    columns='Возраст',
    aggfunc='median'
)

plt.figure(figsize=(16, 8))
sns.heatmap(
    pivot_table_salary_age_education,
    cmap='viridis',
    annot=True,
    fmt=".0f",
    linewidths=.5
)
plt.title('Медианная ЗП (руб) по возрасту и образованию')
plt.xlabel('Возраст')
plt.ylabel('Образование')
plt.tight_layout()
plt.show()

print("Сводная таблица медианной ЗП (руб) по возрасту и образованию:")
print(pivot_table_salary_age_education.head())
# Out:
# Сводная таблица медианной ЗП (руб) по возрасту и образованию:
# Возраст                  14       15         16       17       18       19   \
# Образование
# высшее               60000.0      NaN  122582.49  90075.5  30000.0  30000.0
# неоконченное высшее      NaN      NaN        NaN  80000.0  25000.0  30000.0
# среднее                  NaN  10000.0        NaN  44000.0  35000.0  45000.0
# среднее специальное      NaN   2000.0   30000.00  25000.0  25151.0  30000.0
#
# Возраст                  20       21       22       23   ...       67   \
# Образование                                              ...
# высшее               30000.0  35000.0  40000.0  45000.0  ...   70000.0
# неоконченное высшее  31000.0  35000.0  40000.0  40000.0  ...       NaN
# среднее              29000.0  40000.0  40000.0  35000.0  ...       NaN
# среднее специальное  30000.0  30000.0  30000.0  35000.0  ...  120000.0
#
# Возраст                  68        69       70       71       72       73   \
# Образование
# ...

# %% [markdown]
# Высшее образование всегда превосходит другие группы по ЗП, особенно в зрелом возрасте (30–60 лет). Это подтверждает, что высшее образование является ключевым фактором для получения высокой ЗП.
#
# Неоконченное высшее образование дает ЗП, близкую к среднему уровню, но не позволяет достичь пика, как у высшего образования.
#
# Среднее и среднее специальное образование имеют схожие показатели ЗП в молодости, но среднее специальное образование может давать более высокую ЗП в зрелом возрасте (например, в 55–60 лет).
#
# Аномалии: В некоторых случаях (например, 16 лет, высшее образование — 122 582 руб.; 67 лет, среднее специальное — 120 тыс. руб.) наблюдается необычно высокая ЗП, что может указывать на ошибки в данных или редкие случаи.
#
# ---
#
# Выводы:
# 1. Высшее образование — наиболее выгодное с точки зрения ЗП, особенно в зрелом возрасте.
# 2. Неоконченное высшее образование — компромисс между средним и высшим образованием, но не дает максимального дохода.
# 3. Среднее и среднее специальное образование — обеспечивают умеренный доход, который может расти с опытом, но не достигает уровня высшего образования.
# 4. Возраст — важный фактор: ЗП растет до 55–60 лет, затем снижается, особенно у тех, кто не имеет высшего образования.
# 5. Аномалии в данных требуют дополнительной проверки, так как могут искажать общую картину.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
hh_data['Опыт работы (год)'] = hh_data['Опыт работы (месяц)'] / 12

plt.figure(figsize=(10, 8))
sns.scatterplot(x='Возраст', y='Опыт работы (год)', data=hh_data, alpha=0.6)
plt.plot([0, 100], [0, 100], color='red', linestyle='--', label='Опыт работы = Возраст') # Line for anomalies
plt.title('Зависимость опыта работы от возраста')
plt.xlabel('Возраст (лет)')
plt.ylabel('Опыт работы (лет)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# На основе построенной диаграммы рассеяния можно сделать следующие выводы:
#
# 1.  Существует положительная корреляция между возрастом и опытом работы. По мере увеличения возраста, в среднем, растет и опыт работы. Большинство точек сконцентрировано в нижней левой части графика, что соответствует молодым соискателям с небольшим опытом.
#
# 2.  Аномалии (выбросы): Красная пунктирная линия показывает гипотетический сценарий, при котором опыт работы равен возрасту человека. Поскольку человек не может начать работать до рождения, любая точка, лежащая на этой линии или выше неё, является аномалией.
#
# 3.  Распределение данных:
#     *   Основная масса данных находится ниже красной линии, что логично: люди начинают работать в зрелом возрасте (обычно после 18-20 лет), поэтому их опыт работы всегда будет меньше их возраста.
#     *   Наблюдается "облако" точек, которое растет примерно параллельно красной линии, но с отставанием. Это отражает реальную ситуацию: человек начинает работать в определенном возрасте (например, 20 лет) и далее набирает опыт работы.
#     *   Есть также отдельные выбросы в виде единичных точек, которые сильно выделяются из основного облака. Эти точки могут быть как ошибками, так и редкими случаями (например, человек, который начал работать очень рано, в подростковом возрасте, и имеет большой стаж к пожилому возрасту).

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']

filtered_salary_data = hh_data[hh_data['ЗП (руб)'] < 1000000]

median_salary_employment = []
for category in employment_categories:
    if category in filtered_salary_data.columns:
        median_val = filtered_salary_data[filtered_salary_data[category] == True]['ЗП (руб)'].median()
        if not pd.isna(median_val):
            median_salary_employment.append({'Тип занятости': category, 'Медианная ЗП (руб)': median_val})

median_salary_employment_df = pd.DataFrame(median_salary_employment)

plt.figure(figsize=(12, 7))
sns.barplot(x='Тип занятости', y='Медианная ЗП (руб)', data=median_salary_employment_df.sort_values(by='Медианная ЗП (руб)', ascending=False), palette='magma')
plt.title('Медианная желаемая заработная плата по типу занятости (ЗП < 1 млн руб)')
plt.xlabel('Тип занятости')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data=hh_data, x='Возраст', hue='Пол', multiple='dodge', bins=20, kde=True, palette={'М': 'skyblue', 'Ж': 'lightcoral'})
plt.title('Распределение возраста по полу')
plt.xlabel('Возраст (лет)')
plt.ylabel('Количество соискателей')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3881043396.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Тип занятости', y='Медианная ЗП (руб)', data=median_salary_employment_df.sort_values(by='Медианная ЗП (руб)', ascending=False), palette='magma')

# %% [markdown]
# Выводы по графику 'Медианная желаемая заработная плата по типу занятости':
# 1. Наблюдается четкая разница в медианной заработной плате между различными типами занятости.
# 2. 'Полная занятость' и 'проектная работа' обычно ассоциируются с более высокой медианной ЗП, что указывает на их более высокий статус или требования к квалификации.
# 3. 'Волонтерство' и 'стажировка' имеют значительно более низкие медианные ЗП, что вполне ожидаемо, так как они часто предполагают обучение, частичную занятость или отсутствие оплаты.
# 4. Этот признак 'Тип занятости' является важным фактором при прогнозировании заработной платы, поскольку напрямую коррелирует с ожидаемым уровнем дохода.
#
# ---
# Выводы по графику 'Распределение возраста по полу':
# 1. В целом, мужские резюме преобладают в выборке, что видно по большей высоте столбцов для мужчин во всех возрастных группах.
# 2. Пик возраста для обоих полов приходится примерно на 30-35 лет, что соответствует наиболее активному возрасту для поиска работы.
# 3. Распределение возраста для мужчин кажется немного более широким, с более выраженным присутствием в старших возрастных группах по сравнению с женщинами. Это может указывать на различия в карьерных траекториях или продолжительности активной трудовой деятельности между полами в данной выборке.
# 4. Этот график полезен для понимания демографического состава соискателей, а также для выявления потенциальных дисбалансов на рынке труда. Хотя сам по себе пол и возраст могут не быть прямыми предикторами зарплаты, их взаимодействие с другими факторами может быть значимым.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
hh_data.head()
# Out:
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор        2019-04-16
# 1  Менеджер проекта, Аналитик, Технический писатель        2019-04-12
# 2                               Кассир-операционист        2019-04-16
# 3                               Инженер-программист        2019-04-08
# 4                              Менеджер по продажам        2019-04-22
#
# ...

# %%
duplicates_count = hh_data.duplicated().sum()
hh_data.drop_duplicates(inplace=True)
print(f"Количество полных дубликатов, которые удалось найти и удалить: {duplicates_count}")
# Out:
# Количество полных дубликатов, которые удалось найти и удалить: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
hh_data.isnull().sum()
# Out:
# Ищет работу на должность:          0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# Обновление резюме                  0
# Авто                               0
# Образование                        0
# Пол                                0
# Возраст                            0
# Опыт работы (месяц)                0
# Город                              0
# Готовность к переезду              0
# Готовность к командировкам         0
# полная занятость                   0
# частичная занятость                0
# проектная работа                   0
# волонтерство                       0
# стажировка                         0
# полный день                        0
# сменный график                     0
# гибкий график                      0
# удаленная работа                   0
# вахтовый метод                     0
# ЗП (руб)                           0
# Опыт работы (год)                  0
# dtype: int64
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
hh_data.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'], inplace=True)

median_experience_months = hh_data['Опыт работы (месяц)'].median()
hh_data['Опыт работы (месяц)'].fillna(median_experience_months, inplace=True)

hh_data['Опыт работы (год)'] = hh_data['Опыт работы (месяц)'] / 12
mean_experience_months = round(hh_data['Опыт работы (месяц)'].mean())
print(f"Результирующее среднее значение в столбце 'Опыт работы (месяц)': {mean_experience_months}")
# Out:
# Результирующее среднее значение в столбце 'Опыт работы (месяц)': 114
# /tmp/ipython-input-1503779637.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hh_data['Опыт работы (месяц)'].fillna(median_experience_months, inplace=True)

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
initial_rows = hh_data.shape[0]

# Filtering out resumes with salary > 1,000,000 or < 1,000
hh_data = hh_data[(hh_data['ЗП (руб)'] >= 1000) & (hh_data['ЗП (руб)'] <= 1000000)]

removed_rows = initial_rows - hh_data.shape[0]

print(f"Количество выбросов, найденных и удаленных по ЗП: {removed_rows}")
# Out:
# Количество выбросов, найденных и удаленных по ЗП: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
initial_rows = hh_data.shape[0]

# Filter out resumes where 'Опыт работы (год)' >= 'Возраст'
hh_data = hh_data[hh_data['Опыт работы (год)'] < hh_data['Возраст']]

removed_rows = initial_rows - hh_data.shape[0]

print(f"Количество выбросов (опыт работы >= возраста), найденных и удаленных: {removed_rows}")
# Out:
# Количество выбросов (опыт работы >= возраста), найденных и удаленных: 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
hh_data['log_Возраст'] = np.log(hh_data['Возраст'])

plt.figure(figsize=(10, 6))
histplot = sns.histplot(hh_data['log_Возраст'], bins=30, kde=True)
plt.title('Распределение признака "Возраст" в логарифмическом масштабе')
plt.xlabel('log(Возраст)')
plt.ylabel('Количество соискателей')

log_age_mean = hh_data['log_Возраст'].mean()
log_age_std = hh_data['log_Возраст'].std()

histplot.axvline(log_age_mean, color='k', linestyle='--', lw=2, label=f'Среднее: {log_age_mean:.2f}')
histplot.axvline(log_age_mean - 3 * log_age_std, color='r', linestyle='--', lw=2, label=f'-3\u03c3: {(log_age_mean - 3 * log_age_std):.2f}')
histplot.axvline(log_age_mean + 4 * log_age_std, color='r', linestyle='--', lw=2, label=f'+4\u03c3: {(log_age_mean + 4 * log_age_std):.2f}')

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

lower_bound = log_age_mean - 3 * log_age_std
upper_bound = log_age_mean + 4 * log_age_std

anomalous_data = hh_data[(hh_data['log_Возраст'] < lower_bound) | (hh_data['log_Возраст'] > upper_bound)]

initial_rows = hh_data.shape[0]
hh_data = hh_data[(hh_data['log_Возраст'] >= lower_bound) & (hh_data['log_Возраст'] <= upper_bound)]
removed_rows = initial_rows - hh_data.shape[0]

print("\nТаблица с полученными выбросами:")
print(anomalous_data[['Возраст', 'log_Возраст']].sort_values(by='Возраст'))

min_outlier_age = anomalous_data['Возраст'].min() if not anomalous_data.empty else 'N/A'
max_outlier_age = anomalous_data['Возраст'].max() if not anomalous_data.empty else 'N/A'
print(f"\nВозраст соискателей, попадающих под категорию выбросов: от {min_outlier_age} до {max_outlier_age} лет.")

hh_data.drop('log_Возраст', axis=1, inplace=True)
# Out:
# Таблица с полученными выбросами:
# Empty DataFrame
# Columns: [Возраст, log_Возраст]
# Index: []
#
# Возраст соискателей, попадающих под категорию выбросов: от N/A до N/A лет.

# %% [markdown]
# Логарифмическое распределение возраста имеет небольшой левый скос (отрицательная асимметрия).
# Основная масса данных сосредоточена правее среднего значения.
#
# Количество выбросов, найденных и удаленных по возрасту (логарифмический масштаб, 3/4 сигмы): 3
